# %% [markdown]
# # LSS Results Loader
#
# Reads results from:
# `/Users/xiaoqianxiao/projects/NARSAD/MRI/derivatives/fMRI_analysis/LSS/LSS/`

# %%
from pathlib import Path
import numpy as np
import pandas as pd

LSS_RESULTS_ROOT = Path(r"/Users/xiaoqianxiao/projects/NARSAD/MRI/derivatives/fMRI_analysis/LSS/LSS")
print("LSS results root:", LSS_RESULTS_ROOT)
print("Exists:", LSS_RESULTS_ROOT.exists())
# Out:
# LSS results root: /Users/xiaoqianxiao/projects/NARSAD/MRI/derivatives/fMRI_analysis/LSS/LSS
# Exists: True

# %%
# List top-level items
for p in sorted(LSS_RESULTS_ROOT.glob('*')):
    print(p.name)
# Out:
# .DS_Store
# FearNetwork
# WholeBrain_Parcellation

# %%
# Find common result file types
patterns = ["**/*.npz", "**/*.joblib", "**/*.pkl", "**/*.csv", "**/*.tsv", "**/*.nii", "**/*.nii.gz"]
results = {}
for pat in patterns:
    results[pat] = list(LSS_RESULTS_ROOT.glob(pat))
    print(pat, len(results[pat]))

# Show a sample of each type
for pat, files in results.items():
    if files:
        print("\nSample for", pat)
        for f in files[:10]:
            print(f)
# Out:
# **/*.npz 0
# **/*.joblib 24
# **/*.pkl 0
# **/*.csv 0
# **/*.tsv 0
# **/*.nii 0
# **/*.nii.gz 0
#
# Sample for **/*.joblib
# /Users/xiaoqianxiao/projects/NARSAD/MRI/derivatives/fMRI_analysis/LSS/LSS/FearNetwork/results_pvals.joblib
# /Users/xiaoqianxiao/projects/NARSAD/MRI/derivatives/fMRI_analysis/LSS/LSS/FearNetwork/results_25.joblib
# /Users/xiaoqianxiao/projects/NARSAD/MRI/derivatives/fMRI_analysis/LSS/LSS/FearNetwork/results_13.joblib
# /Users/xiaoqianxiao/projects/NARSAD/MRI/derivatives/fMRI_analysis/LSS/LSS/FearNetwork/results_11.joblib
# /Users/xiaoqianxiao/projects/NARSAD/MRI/derivatives/fMRI_analysis/LSS/LSS/FearNetwork/results_23.joblib
# /Users/xiaoqianxiao/projects/NARSAD/MRI/derivatives/fMRI_analysis/LSS/LSS/FearNetwork/results_maps.joblib
# /Users/xiaoqianxiao/projects/NARSAD/MRI/derivatives/fMRI_analysis/LSS/LSS/FearNetwork/results_21.joblib
# /Users/xiaoqianxiao/projects/NARSAD/MRI/derivatives/fMRI_analysis/LSS/LSS/FearNetwork/results_12.joblib
# /Users/xiaoqianxiao/projects/NARSAD/MRI/derivatives/fMRI_analysis/LSS/LSS/FearNetwork/results_13b.joblib
# /Users/xiaoqianxiao/projects/NARSAD/MRI/derivatives/fMRI_analysis/LSS/LSS/FearNetwork/results_24.joblib

# %%
# List .joblib results and show keys (if dict)
from joblib import load
joblib_files = sorted(LSS_RESULTS_ROOT.glob('**/*.joblib'))
print(f'Joblib files: {len(joblib_files)}')
for f in joblib_files:
    obj = load(f)
    if isinstance(obj, dict):
        print(f"\n{f}")
        print('  keys:', list(obj.keys()))
    else:
        print(f"\n{f}")
        print('  type:', type(obj))
# Out:
# Joblib files: 24
#
# /Users/xiaoqianxiao/projects/NARSAD/MRI/derivatives/fMRI_analysis/LSS/LSS/FearNetwork/results_11.joblib
#   keys: ['acc_sad_cv', 'p_sad', 'acc_hc_cv', 'p_hc', 'func_matrix', 'sim_spatial', 'p_sim', 'map_sad', 'map_hc']
#
# /Users/xiaoqianxiao/projects/NARSAD/MRI/derivatives/fMRI_analysis/LSS/LSS/FearNetwork/results_12.joblib
#   keys: ['rdms_sad', 'rdms_hc', 'metric_a_stats', 'metric_b_stats', 'features_sad', 'features_hc', 'one_sample_stats']
#
# /Users/xiaoqianxiao/projects/NARSAD/MRI/derivatives/fMRI_analysis/LSS/LSS/FearNetwork/results_13.joblib
#   keys: ['safe_sad', 'threat_sad']
#
# /Users/xiaoqianxiao/projects/NARSAD/MRI/derivatives/fMRI_analysis/LSS/LSS/FearNetwork/results_13b.joblib
#   keys: ['stats_safe', 'stats_threat', 'data_safe', 'data_threat']
#
# /Users/xiaoqianxiao/projects/NARSAD/MRI/derivatives/fMRI_analysis/LSS/LSS/FearNetwork/results_14_self.joblib
#   keys: ['df_sad', 'df_hc']
#
# /Users/xiaoqianxiao/projects/NARSAD/MRI/derivatives/fMRI_analysis/LSS/LSS/FearNetwork/results_21.joblib
#   keys: ['df', 'p_safe', 'p_threat']
#
# /Users/xiaoqianxiao/projects/NARSAD/MRI/derivatives/fMRI_analysis/LSS/LSS/FearNetwork/results_22.joblib
#   keys: ['df', 'stats']
#
# /Users/xiaoqianxiao/projects/NARSAD/MRI/derivatives/fMRI_analysis/LSS/LSS/FearNetwork/results_23.joblib
#   keys: ['df', 'stats']
#
# /Users/xiaoqianxiao/projects/NARSAD/MRI/derivatives/fMRI_analysis/LSS/LSS/FearNetwork/results_24.joblib
#   keys: ['acc_plc', 'acc_oxt', 'p_val', 'model']
#
# /Users/xiaoqianxiao/projects/NARSAD/MRI/derivatives/fMRI_analysis/LSS/LSS/FearNetwork/results_25.joblib
#   keys: ['acc_hc_plc', 'acc_hc_oxt', 'model']
#
# /Users/xiaoqianxiao/projects/NARSAD/MRI/derivatives/fMRI_analysis/LSS/LSS/FearNetwork/results_fdr.joblib
#   keys: []
#
# /Users/xiaoqianxiao/projects/NARSAD/MRI/derivatives/fMRI_analysis/LSS/LSS/FearNetwork/results_maps.joblib
#   keys: []
#
# /Users/xiaoqianxiao/projects/NARSAD/MRI/derivatives/fMRI_analysis/LSS/LSS/FearNetwork/results_pvals.joblib
#   keys: []
#
# /Users/xiaoqianxiao/projects/NARSAD/MRI/derivatives/fMRI_analysis/LSS/LSS/WholeBrain_Parcellation/parcel_rsm_results.joblib
#   keys: ['ext_early', 'ext_late', 'ext_delta', 'rst_early', 'rst_late', 'rst_delta']
#
# /Users/xiaoqianxiao/projects/NARSAD/MRI/derivatives/fMRI_analysis/LSS/LSS/WholeBrain_Parcellation/results_11.joblib
#   keys: ['acc_sad_cv', 'p_sad', 'acc_hc_cv', 'p_hc', 'func_matrix', 'sim_spatial', 'p_sim', 'map_sad', 'map_hc']
#
# /Users/xiaoqianxiao/projects/NARSAD/MRI/derivatives/fMRI_analysis/LSS/LSS/WholeBrain_Parcellation/results_12.joblib
#   keys: ['rdms_sad', 'rdms_hc', 'metric_a_stats', 'metric_b_stats', 'features_sad', 'features_hc', 'one_sample_stats']
#
# /Users/xiaoqianxiao/projects/NARSAD/MRI/derivatives/fMRI_analysis/LSS/LSS/WholeBrain_Parcellation/results_13.joblib
#   keys: ['safe_sad', 'threat_sad']
#
# /Users/xiaoqianxiao/projects/NARSAD/MRI/derivatives/fMRI_analysis/LSS/LSS/WholeBrain_Parcellation/results_13b.joblib
#   keys: ['stats_safe', 'stats_threat', 'data_safe', 'data_threat']
#
# /Users/xiaoqianxiao/projects/NARSAD/MRI/derivatives/fMRI_analysis/LSS/LSS/WholeBrain_Parcellation/results_14_self.joblib
#   keys: ['df_sad', 'df_hc']
#
# /Users/xiaoqianxiao/projects/NARSAD/MRI/derivatives/fMRI_analysis/LSS/LSS/WholeBrain_Parcellation/results_21.joblib
#   keys: ['df', 'p_safe', 'p_threat']
#
# /Users/xiaoqianxiao/projects/NARSAD/MRI/derivatives/fMRI_analysis/LSS/LSS/WholeBrain_Parcellation/results_22.joblib
#   keys: ['df', 'stats']
#
# /Users/xiaoqianxiao/projects/NARSAD/MRI/derivatives/fMRI_analysis/LSS/LSS/WholeBrain_Parcellation/results_23.joblib
#   keys: ['df', 'stats']
#
# /Users/xiaoqianxiao/projects/NARSAD/MRI/derivatives/fMRI_analysis/LSS/LSS/WholeBrain_Parcellation/results_24.joblib
#   keys: ['acc_plc', 'acc_oxt', 'p_val', 'model']
#
# /Users/xiaoqianxiao/projects/NARSAD/MRI/derivatives/fMRI_analysis/LSS/LSS/WholeBrain_Parcellation/results_25.joblib
#   keys: ['acc_hc_plc', 'acc_hc_oxt', 'model']
# /Users/xiaoqianxiao/fsl/lib/python3.11/site-packages/sklearn/base.py:376: InconsistentVersionWarning: Trying to unpickle estimator StandardScaler from version 1.3.2 when using version 1.4.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /Users/xiaoqianxiao/fsl/lib/python3.11/site-packages/sklearn/base.py:376: InconsistentVersionWarning: Trying to unpickle estimator LogisticRegression from version 1.3.2 when using version 1.4.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /Users/xiaoqianxiao/fsl/lib/python3.11/site-packages/sklearn/base.py:376: InconsistentVersionWarning: Trying to unpickle estimator Pipeline from version 1.3.2 when using version 1.4.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /Users/xiaoqianxiao/fsl/lib/python3.11/site-packages/sklearn/base.py:376: InconsistentVersionWarning: Trying to unpickle estimator StandardScaler from version 1.3.2 when using version 1.4.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /Users/xiaoqianxiao/fsl/lib/python3.11/site-packages/sklearn/base.py:376: InconsistentVersionWarning: Trying to unpickle estimator LogisticRegression from version 1.3.2 when using version 1.4.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /Users/xiaoqianxiao/fsl/lib/python3.11/site-packages/sklearn/base.py:376: InconsistentVersionWarning: Trying to unpickle estimator Pipeline from version 1.3.2 when using version 1.4.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
# Display joblib results (summary + preview)
from joblib import load
import numpy as np
import pandas as pd


def summarize_value(v):
    if isinstance(v, pd.DataFrame):
        return f"DataFrame shape={v.shape}"
    if isinstance(v, np.ndarray):
        return f"ndarray shape={v.shape}, dtype={v.dtype}"
    if isinstance(v, (list, tuple)):
        return f"{type(v).__name__} len={len(v)}"
    if isinstance(v, dict):
        return f"dict keys={list(v.keys())[:10]}"
    return f"{type(v).__name__}: {str(v)[:200]}"


def preview_value(v):
    if isinstance(v, pd.DataFrame):
        return v.head()
    if isinstance(v, np.ndarray):
        return v[:5]
    if isinstance(v, (list, tuple)):
        return v[:5]
    if isinstance(v, dict):
        return {k: summarize_value(v[k]) for k in list(v.keys())[:10]}
    return v


joblib_files = sorted(LSS_RESULTS_ROOT.glob('**/*.joblib'))
print(f"Joblib files: {len(joblib_files)}")

for f in joblib_files:
    obj = load(f)
    print(f"\n{f}")
    if isinstance(obj, dict):
        for k, v in obj.items():
            print(f"  {k}: {summarize_value(v)}")
        for k in list(obj.keys())[:3]:
            print(f"\n  Preview for {k}:")
            print(preview_value(obj[k]))
    else:
        print('  object:', summarize_value(obj))
# Out:
# Joblib files: 24
#
# /Users/xiaoqianxiao/projects/NARSAD/MRI/derivatives/fMRI_analysis/LSS/LSS/FearNetwork/results_11.joblib
#   acc_sad_cv: float64: 0.76
#   p_sad: float64: 0.0084
#   acc_hc_cv: float64: 0.5900000000000002
#   p_hc: float64: 0.1428
#   func_matrix: ndarray shape=(2, 2), dtype=float64
#   sim_spatial: float64: -0.03484697105856892
#   p_sim: float64: 0.3708
#   map_sad: ndarray shape=(2148,), dtype=float64
#   map_hc: ndarray shape=(2148,), dtype=float64
#
#   Preview for acc_sad_cv:
# 0.76
#
#   Preview for p_sad:
# 0.0084
#
#   Preview for acc_hc_cv:
# 0.5900000000000002
#
# /Users/xiaoqianxiao/projects/NARSAD/MRI/derivatives/fMRI_analysis/LSS/LSS/FearNetwork/results_12.joblib
#   rdms_sad: ndarray shape=(23, 3, 3), dtype=float64
#   rdms_hc: ndarray shape=(28, 3, 3), dtype=float64
#   metric_a_stats: tuple len=2
#   metric_b_stats: tuple len=2
#   features_sad: int64: 109
#   features_hc: int64: 108
#   one_sample_stats: dict keys=['p_a_sad', 'p_a_hc', 'p_b_sad', 'p_b_hc']
#
#   Preview for rdms_sad:
# [[[ 0.         20.28938435 23.03137539]
#   [20.28938435  0.         36.86303093]
#   [23.03137539 36.86303093  0.        ]]
#
#  [[ 0.         14.14382092 21.2249765 ]
#   [14.14382092  0.         25.04748932]
#   [21.2249765  25.04748932  0.        ]]
#
#  [[ 0.         46.14749405 44.33901428]
#   [46.14749405  0.         74.6739064 ]
#   [44.33901428 74.6739064   0.        ]]
#
#  [[ 0.         32.52200851 38.66940567]
#   [32.52200851  0.         32.97049072]
#   [38.66940567 32.97049072  0.        ]]
#
#  [[ 0.          4.37323989 10.78521454]
#   [ 4.37323989  0.         19.68038177]
#   [10.78521454 19.68038177  0.        ]]]
#
#   Preview for rdms_hc:
# [[[ 0.         39.57343231 35.15811958]
#   [39.57343231  0.         48.10190872]
#   [35.15811958 48.10190872  0.        ]]
#
#  [[ 0.         17.60596676 18.18888664]
#   [17.60596676  0.         14.9253824 ]
#   [18.18888664 14.9253824   0.        ]]
#
#  [[ 0.         14.14992773  9.24385081]
#   [14.14992773  0.          7.60147326]
#   [ 9.24385081  7.60147326  0.        ]]
#
#  [[ 0.         22.45907269 20.18682602]
#   [22.45907269  0.         20.09899067]
#   [20.18682602 20.09899067  0.        ]]
#
#  [[ 0.         20.64834167 48.09133919]
#   [20.64834167  0.         39.33853874]
#   [48.09133919 39.33853874  0.        ]]]
#
#   Preview for metric_a_stats:
# (1.0458154947830116, 0.3016)
#
# /Users/xiaoqianxiao/projects/NARSAD/MRI/derivatives/fMRI_analysis/LSS/LSS/FearNetwork/results_13.joblib
#   safe_sad: DataFrame shape=(23, 4)
#   threat_sad: DataFrame shape=(22, 4)
#
#   Preview for safe_sad:
#     sub   projection    cosine     init_dist
# 0  N101  1086.319336  0.271178  10242.785156
# 1  N110   725.850098  0.211528   6354.571777
# 2  N111   961.813965  0.256713   7922.499023
# 3  N112  1327.390137  0.326922   8614.078125
# 4  N114   734.269592  0.186432   6626.396973
#
#   Preview for threat_sad:
#     sub   projection    cosine    init_dist
# 0  N101  3410.996338  0.715959  4672.286621
# 1  N110  1528.731079  0.520127  2764.306396
# 2  N111  1656.899414  0.460679  3317.318359
# 3  N112  2196.961914  0.525398  2898.383057
# 4  N114  8015.145508  0.921844  6702.920410
#
# /Users/xiaoqianxiao/projects/NARSAD/MRI/derivatives/fMRI_analysis/LSS/LSS/FearNetwork/results_13b.joblib
#   stats_safe: DataFrame shape=(8, 13)
#   stats_threat: DataFrame shape=(8, 13)
#   data_safe: DataFrame shape=(408, 5)
#   data_threat: DataFrame shape=(400, 5)
#
#   Preview for stats_safe:
#    Trial     SAD_t  SAD_df         SAD_p      HC_t  HC_df          HC_p  \
# 0      1  0.261609      22  3.980283e-01  3.308731     27  1.330627e-03
# 1      2 -0.783842      22  7.792544e-01 -0.489670     27  6.858389e-01
# 2      3  0.837955      22  2.055338e-01 -1.025122     27  8.427985e-01
# 3      4 -0.755808      22  7.711094e-01 -1.083569     27  8.559312e-01
# 4      5  7.540918      22  7.761031e-08  6.280104     27  5.073973e-07
#
#      Diff_t  Diff_df    Diff_p     SAD_p_fdr  HC_p_fdr  Diff_p_fdr
# 0 -1.027179       49  0.309380  5.307044e-01  0.003548    0.618761
# 1 -0.199598       49  0.842621  7.792544e-01  0.855931    0.880582
# 2  1.307959       49  0.196990  3.288540e-01  0.855931    0.557016
# 3  0.151018       49  0.880582  7.792544e-01  0.855931    0.880582
# 4  0.706631       49  0.483142  6.208825e-07  0.000004    0.644190
#
#   Preview for stats_threat:
#    Trial     SAD_t  SAD_df         SAD_p       HC_t  HC_df          HC_p  \
# 0      1 -0.913058      21  8.142119e-01  -0.291028     27  6.133729e-01
# 1      2 -1.620706      21  9.399997e-01  -0.838226     27  7.953684e-01
# 2      3  2.047508      21  2.666091e-02   0.001176     27  4.995351e-01
# 3      4  2.643072      21  7.603695e-03   1.798243     27  4.166475e-02
# 4      5  9.353302      21  3.082283e-09  11.314112     27  4.712447e-12
#
#      Diff_t  Diff_df    Diff_p     SAD_p_fdr      HC_p_fdr  Diff_p_fdr
# 0 -0.434631       48  0.665778  9.305279e-01  7.009976e-01    0.801170
# 1 -0.469362       48  0.640936  9.399997e-01  7.953684e-01    0.801170
# 2  1.308859       48  0.196814  3.554789e-02  6.660468e-01    0.787256
# 3  0.253233       48  0.801170  1.216591e-02  6.666360e-02    0.801170
# 4 -0.331809       48  0.741478  1.232913e-08  1.884979e-11    0.801170
#
#   Preview for data_safe:
#     sub  trial     score Group        Condition
# 0  N101      1  0.042296   SAD  Safety Learning
# 1  N101      2 -0.035005   SAD  Safety Learning
# 2  N101      3  0.086130   SAD  Safety Learning
# 3  N101      4 -0.093421   SAD  Safety Learning
# 4  N101      5  0.175602   SAD  Safety Learning
#
# /Users/xiaoqianxiao/projects/NARSAD/MRI/derivatives/fMRI_analysis/LSS/LSS/FearNetwork/results_14_self.joblib
#   df_sad: DataFrame shape=(23, 7)
#   df_hc: DataFrame shape=(28, 7)
#
#   Preview for df_sad:
#     sub   entropy  kurtosis  variance  \
# 0  N101  0.878982  1.731860  0.034129
# 1  N110  0.964950 -1.256610  0.009919
# 2  N111  0.904105 -0.941199  0.028379
# 3  N112  0.941489 -1.265615  0.016978
# 4  N114  0.974018  1.019808  0.008705
#
#                                        probabilities     brier  \
# 0  [0.3603570706618762, 0.4961798834201803, 0.330...  0.291236
# 1  [0.5134309834616668, 0.3397683218377037, 0.403...  0.263506
# 2  [0.4395856211243925, 0.41341780115022714, 0.70...  0.266169
# 3  [0.4011200917724668, 0.6053965032565977, 0.765...  0.300700
# 4  [0.5338304263358327, 0.5049625174126814, 0.570...  0.287461
#
#                                                calib
# 0  {'frac_pos': [0.3333333333333333, 0.5, 1.0, 0....
# 1  {'frac_pos': [0.6, 0.4444444444444444, 0.5], '...
# 2  {'frac_pos': [0.0, 0.6666666666666666, 0.25, 0...
# 3  {'frac_pos': [0.6666666666666666, 0.6666666666...
# 4  {'frac_pos': [0.75, 0.4, 0.5], 'mean_pred': [0...
#
#   Preview for df_hc:
#     sub   entropy  kurtosis  variance  \
# 0  N201  0.971598 -0.763436  0.009553
# 1  N204  0.978180 -1.257136  0.006598
# 2  N206  0.967459 -0.649623  0.010379
# 3  N207  0.972033 -0.311079  0.008160
# 4  N209  0.966262 -0.317419  0.009806
#
#                                        probabilities     brier  \
# 0  [0.5343219024258697, 0.4076103622350284, 0.503...  0.300789
# 1  [0.4231783713379096, 0.531128886871583, 0.4558...  0.277732
# 2  [0.6657678639155056, 0.45956819227852597, 0.72...  0.287604
# 3  [0.38059223897141486, 0.6507443133352707, 0.40...  0.236488
# 4  [0.26890085736344205, 0.500252515432274, 0.409...  0.286454
#
#                                                calib
# 0  {'frac_pos': [0.8333333333333334, 0.3], 'mean_...
# 1  {'frac_pos': [1.0, 0.5, 0.3333333333333333], '...
# 2  {'frac_pos': [1.0, 0.4, 0.5], 'mean_pred': [0....
# 3  {'frac_pos': [0.25, 0.6, 0.5], 'mean_pred': [0...
# 4  {'frac_pos': [0.6, 0.5, 0.0], 'mean_pred': [0....
#
# /Users/xiaoqianxiao/projects/NARSAD/MRI/derivatives/fMRI_analysis/LSS/LSS/FearNetwork/results_21.joblib
#   df: DataFrame shape=(102, 6)
#   p_safe: float64: 0.980508072049339
#   p_threat: float64: 0.9599927900251004
#
#   Preview for df:
#   Subject Group     Drug    Condition  Dist_Safety  Dist_Threat
# 0    N101   SAD  Placebo  SAD_Placebo     0.041263     0.066257
# 1    N110   SAD  Placebo  SAD_Placebo     0.062069     0.057761
# 2    N111   SAD  Placebo  SAD_Placebo     0.153919     0.199244
# 3    N112   SAD  Placebo  SAD_Placebo     0.041794     0.027507
# 4    N114   SAD  Placebo  SAD_Placebo     0.087365     0.498431
#
#   Preview for p_safe:
# 0.980508072049339
#
#   Preview for p_threat:
# 0.9599927900251004
#
# /Users/xiaoqianxiao/projects/NARSAD/MRI/derivatives/fMRI_analysis/LSS/LSS/FearNetwork/results_22.joblib
#   df: DataFrame shape=(202, 6)
#   stats: dict keys=['Safety_Cosine', 'Safety_Projection', 'Threat_Cosine', 'Threat_Projection']
#
#   Preview for df:
#   Subject Group     Drug  Domain    Cosine  Projection
# 0    N101   SAD  Placebo  Safety  0.574206  462.647797
# 1    N101   SAD  Placebo  Threat  0.342528  294.132812
# 2    N110   SAD  Placebo  Safety  0.519406  319.958313
# 3    N110   SAD  Placebo  Threat  0.095285   60.141571
# 4    N111   SAD  Placebo  Safety  0.606255  463.488831
#
#   Preview for stats:
# {'Safety_Cosine': 'float64: 0.06624896477479117', 'Safety_Projection': 'float64: 0.03292210578985362', 'Threat_Cosine': 'float64: 0.07606543823444499', 'Threat_Projection': 'float64: 0.3720272480692114'}
#
# /Users/xiaoqianxiao/projects/NARSAD/MRI/derivatives/fMRI_analysis/LSS/LSS/FearNetwork/results_23.joblib
#   df: DataFrame shape=(102, 6)
#   stats: dict keys=['Entropy', 'Kurtosis', 'Variance']
#
#   Preview for df:
#   Subject Group     Drug   Entropy  Kurtosis  Variance
# 0    N101   SAD  Placebo  0.871261  1.704546  0.034834
# 1    N110   SAD  Placebo  0.967179 -1.227639  0.009418
# 2    N111   SAD  Placebo  0.905433 -0.890950  0.028462
# 3    N112   SAD  Placebo  0.945019 -1.184217  0.016132
# 4    N114   SAD  Placebo  0.975060  1.230817  0.008366
#
#   Preview for stats:
# {'Entropy': 'float64: 0.6519212815264137', 'Kurtosis': 'float64: 0.9659258150240206', 'Variance': 'float64: 0.3659193884877384'}
#
# /Users/xiaoqianxiao/projects/NARSAD/MRI/derivatives/fMRI_analysis/LSS/LSS/FearNetwork/results_24.joblib
#   acc_plc: ndarray shape=(23,), dtype=float64
#   acc_oxt: ndarray shape=(27,), dtype=float64
#   p_val: float64: 0.1739302742278852
#   model: Pipeline: Pipeline(steps=[('scaler', StandardScaler()),
#                 ('classification',
#                  LogisticRegression(C=0.01, class_weight='balanced',
#                                     max_iter=5000,
#
#   Preview for acc_plc:
# [0.  1.  1.  0.5 0. ]
#
#   Preview for acc_oxt:
# [1.  0.5 0.5 0.  0.5]
#
#   Preview for p_val:
# 0.1739302742278852
#
# /Users/xiaoqianxiao/projects/NARSAD/MRI/derivatives/fMRI_analysis/LSS/LSS/FearNetwork/results_25.joblib
#   acc_hc_plc: ndarray shape=(28,), dtype=float64
#   acc_hc_oxt: ndarray shape=(24,), dtype=float64
#   model: Pipeline: Pipeline(steps=[('scaler', StandardScaler()),
#                 ('classification',
#                  LogisticRegression(class_weight='balanced', max_iter=5000,
#                                     n_jobs=
#
#   Preview for acc_hc_plc:
# [0.5 1.  0.5 1.  0.5]
#
#   Preview for acc_hc_oxt:
# [0.5 1.  0.5 1.  0. ]
#
#   Preview for model:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('classification',
#                  LogisticRegression(class_weight='balanced', max_iter=5000,
#                                     n_jobs=1, random_state=42))])
#
# /Users/xiaoqianxiao/projects/NARSAD/MRI/derivatives/fMRI_analysis/LSS/LSS/FearNetwork/results_fdr.joblib
#
# /Users/xiaoqianxiao/projects/NARSAD/MRI/derivatives/fMRI_analysis/LSS/LSS/FearNetwork/results_maps.joblib
#
# /Users/xiaoqianxiao/projects/NARSAD/MRI/derivatives/fMRI_analysis/LSS/LSS/FearNetwork/results_pvals.joblib
#
# /Users/xiaoqianxiao/projects/NARSAD/MRI/derivatives/fMRI_analysis/LSS/LSS/WholeBrain_Parcellation/parcel_rsm_results.joblib
#   ext_early: ndarray shape=(3, 3), dtype=float64
#   ext_late: ndarray shape=(3, 3), dtype=float64
#   ext_delta: ndarray shape=(3, 3), dtype=float64
#   rst_early: ndarray shape=(3, 3), dtype=float64
#   rst_late: ndarray shape=(3, 3), dtype=float64
#   rst_delta: ndarray shape=(3, 3), dtype=float64
#
#   Preview for ext_early:
# [[0.         0.1580547  0.16693977]
#  [0.1580547  0.         0.14866444]
#  [0.16693977 0.14866444 0.        ]]
#
#   Preview for ext_late:
# [[0.         0.18256005 0.19148871]
#  [0.18256005 0.         0.17821647]
#  [0.19148871 0.17821647 0.        ]]
#
#   Preview for ext_delta:
# [[0.         0.02450535 0.02454894]
#  [0.02450535 0.         0.02955203]
#  [0.02454894 0.02955203 0.        ]]
#
# /Users/xiaoqianxiao/projects/NARSAD/MRI/derivatives/fMRI_analysis/LSS/LSS/WholeBrain_Parcellation/results_11.joblib
#   acc_sad_cv: float64: 0.87
#   p_sad: float64: 0.0
#   acc_hc_cv: float64: 0.7966666666666667
#   p_hc: float64: 0.0006
#   func_matrix: ndarray shape=(2, 2), dtype=float64
#   sim_spatial: float64: 0.06747149956328034
#   p_sim: float64: 0.7384
#   map_sad: ndarray shape=(414,), dtype=float64
#   map_hc: ndarray shape=(414,), dtype=float64
#
#   Preview for acc_sad_cv:
# 0.87
#
#   Preview for p_sad:
# 0.0
#
#   Preview for acc_hc_cv:
# 0.7966666666666667
#
# /Users/xiaoqianxiao/projects/NARSAD/MRI/derivatives/fMRI_analysis/LSS/LSS/WholeBrain_Parcellation/results_12.joblib
#   rdms_sad: ndarray shape=(23, 3, 3), dtype=float64
#   rdms_hc: ndarray shape=(28, 3, 3), dtype=float64
#   metric_a_stats: tuple len=2
#   metric_b_stats: tuple len=2
#   features_sad: int64: 21
#   features_hc: int64: 21
#   one_sample_stats: dict keys=['p_a_sad', 'p_a_hc', 'p_b_sad', 'p_b_hc']
#
#   Preview for rdms_sad:
# [[[ 0.          2.04223054  6.37218755]
#   [ 2.04223054  0.          2.62471672]
#   [ 6.37218755  2.62471672  0.        ]]
#
#  [[ 0.          1.98471392  6.02132239]
#   [ 1.98471392  0.          6.90402662]
#   [ 6.02132239  6.90402662  0.        ]]
#
#  [[ 0.          5.40504168 12.18144644]
#   [ 5.40504168  0.         10.74489395]
#   [12.18144644 10.74489395  0.        ]]
#
#  [[ 0.         -0.22336817 -0.92715953]
#   [-0.22336817  0.          1.16703791]
#   [-0.92715953  1.16703791  0.        ]]
#
#  [[ 0.         -0.49096948  2.70535332]
#   [-0.49096948  0.          0.74121805]
#   [ 2.70535332  0.74121805  0.        ]]]
#
#   Preview for rdms_hc:
# [[[ 0.          7.12231307  3.17893178]
#   [ 7.12231307  0.          4.04992464]
#   [ 3.17893178  4.04992464  0.        ]]
#
#  [[ 0.          2.21425338  5.76238195]
#   [ 2.21425338  0.          6.90392511]
#   [ 5.76238195  6.90392511  0.        ]]
#
#  [[ 0.         11.17384741  3.23607501]
#   [11.17384741  0.          6.65442889]
#   [ 3.23607501  6.65442889  0.        ]]
#
#  [[ 0.          7.60248795  4.78595837]
#   [ 7.60248795  0.          3.19917114]
#   [ 4.78595837  3.19917114  0.        ]]
#
#  [[ 0.          0.4516941   9.57339758]
#   [ 0.4516941   0.          8.48725786]
#   [ 9.57339758  8.48725786  0.        ]]]
#
#   Preview for metric_a_stats:
# (-0.9088436528573742, 0.37)
#
# /Users/xiaoqianxiao/projects/NARSAD/MRI/derivatives/fMRI_analysis/LSS/LSS/WholeBrain_Parcellation/results_13.joblib
#   safe_sad: DataFrame shape=(23, 4)
#   threat_sad: DataFrame shape=(22, 4)
#
#   Preview for safe_sad:
#     sub  projection    cosine    init_dist
# 0  N101  153.734131  0.237550  1480.437866
# 1  N110  202.770981  0.260181   873.431946
# 2  N111  181.013687  0.334430  1646.997070
# 3  N112  159.121002  0.258791  1263.714600
# 4  N114   44.752327  0.061045  1434.877197
#
#   Preview for threat_sad:
#     sub  projection    cosine   init_dist
# 0  N101  278.102142  0.475236  417.330078
# 1  N110  189.082367  0.393581  486.070068
# 2  N111   42.666573  0.076906  534.750732
# 3  N112  312.740479  0.604649  407.422852
# 4  N114  764.606873  0.739392  621.276428
#
# /Users/xiaoqianxiao/projects/NARSAD/MRI/derivatives/fMRI_analysis/LSS/LSS/WholeBrain_Parcellation/results_13b.joblib
#   stats_safe: DataFrame shape=(8, 13)
#   stats_threat: DataFrame shape=(8, 13)
#   data_safe: DataFrame shape=(408, 5)
#   data_threat: DataFrame shape=(400, 5)
#
#   Preview for stats_safe:
#    Trial     SAD_t  SAD_df     SAD_p      HC_t  HC_df      HC_p    Diff_t  \
# 0      1  2.215551      22  0.018689  0.623781     27  0.269003  0.851369
# 1      2 -0.505533      22  0.690894  0.084458     27  0.466658 -0.428688
# 2      3  0.931765      22  0.180786  0.665617     27  0.255651  0.125595
# 3      4 -1.846637      22  0.960852 -1.447129     27  0.920314 -0.470658
# 4      5  4.051540      22  0.000266  4.152945     27  0.000147 -0.630381
#
#    Diff_df    Diff_p  SAD_p_fdr  HC_p_fdr  Diff_p_fdr
# 0       49  0.398706   0.037533  0.358671    0.779840
# 1       49  0.670029   0.789593  0.533323    0.779840
# 2       49  0.900567   0.289257  0.358671    0.900567
# 3       49  0.639973   0.960852  0.920314    0.779840
# 4       49  0.531374   0.001545  0.001180    0.779840
#
#   Preview for stats_threat:
#    Trial     SAD_t  SAD_df     SAD_p      HC_t  HC_df      HC_p    Diff_t  \
# 0      1 -0.134112      21  0.552704  0.695452     27  0.246357 -0.563759
# 1      2 -0.390269      21  0.649866 -0.387055     27  0.649125  0.028376
# 2      3 -0.201654      21  0.578936 -1.374693     27  0.909735  0.853355
# 3      4  1.140001      21  0.133561  1.359028     27  0.092691 -0.322994
# 4      5  4.362936      21  0.000136  4.135770     27  0.000154  0.028149
#
#    Diff_df    Diff_p  SAD_p_fdr  HC_p_fdr  Diff_p_fdr
# 0       48  0.575543   0.649866  0.328476    0.920869
# 1       48  0.977480   0.649866  0.741857    0.977660
# 2       48  0.397701   0.649866  0.909735    0.920869
# 3       48  0.748103   0.213698  0.148306    0.977660
# 4       48  0.977660   0.000364  0.000412    0.977660
#
#   Preview for data_safe:
#     sub  trial     score Group        Condition
# 0  N101      1  0.033582   SAD  Safety Learning
# 1  N101      2 -0.227702   SAD  Safety Learning
# 2  N101      3  0.150404   SAD  Safety Learning
# 3  N101      4  0.043716   SAD  Safety Learning
# 4  N101      5  0.154346   SAD  Safety Learning
#
# /Users/xiaoqianxiao/projects/NARSAD/MRI/derivatives/fMRI_analysis/LSS/LSS/WholeBrain_Parcellation/results_14_self.joblib
#   df_sad: DataFrame shape=(23, 7)
#   df_hc: DataFrame shape=(28, 7)
#
#   Preview for df_sad:
#     sub   entropy  kurtosis  variance  \
# 0  N101  0.883444 -0.284573  0.017770
# 1  N110  0.957474  0.502990  0.011607
# 2  N111  0.782518 -1.295088  0.029971
# 3  N112  0.966947 -1.396948  0.007750
# 4  N114  0.932525 -0.959005  0.018305
#
#                                        probabilities     brier  \
# 0  [0.7351394204566368, 0.6332073157566814, 0.690...  0.318746
# 1  [0.5199354147266878, 0.42908594767382163, 0.34...  0.274591
# 2  [0.08331390056425332, 0.2989681592624906, 0.20...  0.135278
# 3  [0.5094665599816719, 0.68992878294435, 0.56123...  0.274622
# 4  [0.4842276882753344, 0.476003838616805, 0.3825...  0.285268
#
#                                                calib
# 0  {'frac_pos': [0.7, 0.0, 0.5], 'mean_pred': [0....
# 1  {'frac_pos': [1.0, 0.0, 0.4444444444444444, 0....
# 2  {'frac_pos': [0.0, 0.25, 0.25, 1.0, 1.0], 'mea...
# 3  {'frac_pos': [0.5833333333333334, 0.25], 'mean...
# 4  {'frac_pos': [0.5, 0.5555555555555556, 0.5, 0....
#
#   Preview for df_hc:
#     sub   entropy  kurtosis  variance  \
# 0  N201  0.907263 -1.360791  0.024080
# 1  N204  0.972654  0.706726  0.007657
# 2  N206  0.948227 -0.541765  0.017333
# 3  N207  0.990283  0.318357  0.003118
# 4  N209  0.944149 -0.456360  0.018196
#
#                                        probabilities     brier  \
# 0  [0.551624506021632, 0.16259235295805208, 0.278...  0.245334
# 1  [0.45140628655173565, 0.5235862248769321, 0.41...  0.216675
# 2  [0.6381305749758474, 0.4907330256415097, 0.397...  0.273594
# 3  [0.45829433300489925, 0.5337444385852672, 0.44...  0.276217
# 4  [0.4938349323664002, 0.5937306394093489, 0.494...  0.251908
#
#                                                calib
# 0  {'frac_pos': [0.0, 0.4, 0.625, 0.5], 'mean_pre...
# 1  {'frac_pos': [0.0, 0.46153846153846156, 1.0], ...
# 2  {'frac_pos': [1.0, 0.0, 0.5555555555555556, 0....
# 3  {'frac_pos': [1.0, 0.4166666666666667, 0.5], '...
# 4  {'frac_pos': [0.4, 0.5, 0.6666666666666666], '...
#
# /Users/xiaoqianxiao/projects/NARSAD/MRI/derivatives/fMRI_analysis/LSS/LSS/WholeBrain_Parcellation/results_21.joblib
#   df: DataFrame shape=(102, 6)
#   p_safe: float64: 0.07362591327313864
#   p_threat: float64: 0.17048383354339036
#
#   Preview for df:
#   Subject Group     Drug    Condition  Dist_Safety  Dist_Threat
# 0    N101   SAD  Placebo  SAD_Placebo     0.114682     0.115414
# 1    N110   SAD  Placebo  SAD_Placebo     0.076758     0.109158
# 2    N111   SAD  Placebo  SAD_Placebo     0.301304     0.524500
# 3    N112   SAD  Placebo  SAD_Placebo     0.028211     0.022201
# 4    N114   SAD  Placebo  SAD_Placebo     0.060264     0.172163
#
#   Preview for p_safe:
# 0.07362591327313864
#
#   Preview for p_threat:
# 0.17048383354339036
#
# /Users/xiaoqianxiao/projects/NARSAD/MRI/derivatives/fMRI_analysis/LSS/LSS/WholeBrain_Parcellation/results_22.joblib
#   df: DataFrame shape=(202, 6)
#   stats: dict keys=['Safety_Cosine', 'Safety_Projection', 'Threat_Cosine', 'Threat_Projection']
#
#   Preview for df:
#   Subject Group     Drug  Domain    Cosine  Projection
# 0    N101   SAD  Placebo  Safety  0.712616  116.784317
# 1    N101   SAD  Placebo  Threat  0.545953   75.239044
# 2    N110   SAD  Placebo  Safety  0.743947  113.285355
# 3    N110   SAD  Placebo  Threat  0.608095   77.010857
# 4    N111   SAD  Placebo  Safety  0.045159    4.465320
#
#   Preview for stats:
# {'Safety_Cosine': 'float64: 0.5673398226857593', 'Safety_Projection': 'float64: 0.35277760337765174', 'Threat_Cosine': 'float64: 0.7628962720513877', 'Threat_Projection': 'float64: 0.5988028438684918'}
#
# /Users/xiaoqianxiao/projects/NARSAD/MRI/derivatives/fMRI_analysis/LSS/LSS/WholeBrain_Parcellation/results_23.joblib
#   df: DataFrame shape=(102, 6)
#   stats: dict keys=['Entropy', 'Kurtosis', 'Variance']
#
#   Preview for df:
#   Subject Group     Drug   Entropy  Kurtosis  Variance
# 0    N101   SAD  Placebo  0.864954 -0.440188  0.019352
# 1    N110   SAD  Placebo  0.980301 -0.538675  0.005811
# 2    N111   SAD  Placebo  0.794912 -1.232790  0.028380
# 3    N112   SAD  Placebo  0.974127 -0.907677  0.005743
# 4    N114   SAD  Placebo  0.926811 -1.094083  0.019550
#
#   Preview for stats:
# {'Entropy': 'float64: 0.7313530226231064', 'Kurtosis': 'float64: 0.12547511944874915', 'Variance': 'float64: 0.8252113824949321'}
#
# /Users/xiaoqianxiao/projects/NARSAD/MRI/derivatives/fMRI_analysis/LSS/LSS/WholeBrain_Parcellation/results_24.joblib
#   acc_plc: ndarray shape=(23,), dtype=float64
#   acc_oxt: ndarray shape=(27,), dtype=float64
#   p_val: float64: 0.7254759448139754
#   model: Pipeline: Pipeline(steps=[('scaler', StandardScaler()),
#                 ('classification',
#                  LogisticRegression(C=0.11288378916846889,
#                                     class_weight='balanced',
#
#   Preview for acc_plc:
# [0.5 1.  1.  0.5 1. ]
#
#   Preview for acc_oxt:
# [1.  1.  0.  0.5 0.5]
#
#   Preview for p_val:
# 0.7254759448139754
#
# /Users/xiaoqianxiao/projects/NARSAD/MRI/derivatives/fMRI_analysis/LSS/LSS/WholeBrain_Parcellation/results_25.joblib
#   acc_hc_plc: ndarray shape=(28,), dtype=float64
#   acc_hc_oxt: ndarray shape=(24,), dtype=float64
#   model: Pipeline: Pipeline(steps=[('scaler', StandardScaler()),
#                 ('classification',
#                  LogisticRegression(class_weight='balanced', max_iter=5000,
#                                     n_jobs=
#
#   Preview for acc_hc_plc:
# [0.5 0.5 1.  1.  1. ]
#
#   Preview for acc_hc_oxt:
# [1. 1. 1. 1. 1.]
#
#   Preview for model:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('classification',
#                  LogisticRegression(class_weight='balanced', max_iter=5000,
#                                     n_jobs=1, random_state=42))])
# /Users/xiaoqianxiao/fsl/lib/python3.11/site-packages/sklearn/base.py:376: InconsistentVersionWarning: Trying to unpickle estimator StandardScaler from version 1.3.2 when using version 1.4.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /Users/xiaoqianxiao/fsl/lib/python3.11/site-packages/sklearn/base.py:376: InconsistentVersionWarning: Trying to unpickle estimator LogisticRegression from version 1.3.2 when using version 1.4.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /Users/xiaoqianxiao/fsl/lib/python3.11/site-packages/sklearn/base.py:376: InconsistentVersionWarning: Trying to unpickle estimator Pipeline from version 1.3.2 when using version 1.4.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /Users/xiaoqianxiao/fsl/lib/python3.11/site-packages/sklearn/base.py:376: InconsistentVersionWarning: Trying to unpickle estimator StandardScaler from version 1.3.2 when using version 1.4.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /Users/xiaoqianxiao/fsl/lib/python3.11/site-packages/sklearn/base.py:376: InconsistentVersionWarning: Trying to unpickle estimator LogisticRegression from version 1.3.2 when using version 1.4.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /Users/xiaoqianxiao/fsl/lib/python3.11/site-packages/sklearn/base.py:376: InconsistentVersionWarning: Trying to unpickle estimator Pipeline from version 1.3.2 when using version 1.4.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
# Summarize results across joblib files
from joblib import load
import numpy as np
import pandas as pd

def scalarify(v):
    if isinstance(v, (int, float, np.integer, np.floating)):
        return float(v)
    if isinstance(v, np.ndarray) and v.size == 1:
        return float(v.ravel()[0])
    return None

rows = []
for f in sorted(LSS_RESULTS_ROOT.glob('**/*.joblib')):
    obj = load(f)
    if not isinstance(obj, dict):
        rows.append({"file": str(f), "type": type(obj).__name__})
        continue
    row = {"file": str(f), "type": "dict", "keys": list(obj.keys())}
    for k in obj.keys():
        val = obj[k]
        sc = scalarify(val)
        if sc is not None:
            row[k] = sc
    rows.append(row)

df_summary = pd.DataFrame(rows)
display(df_summary)

metric_cols = [c for c in df_summary.columns if c not in ["file", "type", "keys"]]
if metric_cols:
    display(df_summary[["file"] + metric_cols])
else:
    print('No scalar metrics found to summarize.')
# Out:
# /Users/xiaoqianxiao/fsl/lib/python3.11/site-packages/sklearn/base.py:376: InconsistentVersionWarning: Trying to unpickle estimator StandardScaler from version 1.3.2 when using version 1.4.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /Users/xiaoqianxiao/fsl/lib/python3.11/site-packages/sklearn/base.py:376: InconsistentVersionWarning: Trying to unpickle estimator LogisticRegression from version 1.3.2 when using version 1.4.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /Users/xiaoqianxiao/fsl/lib/python3.11/site-packages/sklearn/base.py:376: InconsistentVersionWarning: Trying to unpickle estimator Pipeline from version 1.3.2 when using version 1.4.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /Users/xiaoqianxiao/fsl/lib/python3.11/site-packages/sklearn/base.py:376: InconsistentVersionWarning: Trying to unpickle estimator StandardScaler from version 1.3.2 when using version 1.4.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /Users/xiaoqianxiao/fsl/lib/python3.11/site-packages/sklearn/base.py:376: InconsistentVersionWarning: Trying to unpickle estimator LogisticRegression from version 1.3.2 when using version 1.4.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /Users/xiaoqianxiao/fsl/lib/python3.11/site-packages/sklearn/base.py:376: InconsistentVersionWarning: Trying to unpickle estimator Pipeline from version 1.3.2 when using version 1.4.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
#                                                  file  type  \
# 0   /Users/xiaoqianxiao/projects/NARSAD/MRI/deriva...  dict
# 1   /Users/xiaoqianxiao/projects/NARSAD/MRI/deriva...  dict
# 2   /Users/xiaoqianxiao/projects/NARSAD/MRI/deriva...  dict
# 3   /Users/xiaoqianxiao/projects/NARSAD/MRI/deriva...  dict
# 4   /Users/xiaoqianxiao/projects/NARSAD/MRI/deriva...  dict
# 5   /Users/xiaoqianxiao/projects/NARSAD/MRI/deriva...  dict
# 6   /Users/xiaoqianxiao/projects/NARSAD/MRI/deriva...  dict
# 7   /Users/xiaoqianxiao/projects/NARSAD/MRI/deriva...  dict
# 8   /Users/xiaoqianxiao/projects/NARSAD/MRI/deriva...  dict
# 9   /Users/xiaoqianxiao/projects/NARSAD/MRI/deriva...  dict
# 10  /Users/xiaoqianxiao/projects/NARSAD/MRI/deriva...  dict
# 11  /Users/xiaoqianxiao/projects/NARSAD/MRI/deriva...  dict
# 12  /Users/xiaoqianxiao/projects/NARSAD/MRI/deriva...  dict
# 13  /Users/xiaoqianxiao/projects/NARSAD/MRI/deriva...  dict
# 14  /Users/xiaoqianxiao/projects/NARSAD/MRI/deriva...  dict
# 15  /Users/xiaoqianxiao/projects/NARSAD/MRI/deriva...  dict
# 16  /Users/xiaoqianxiao/projects/NARSAD/MRI/deriva...  dict
# 17  /Users/xiaoqianxiao/projects/NARSAD/MRI/deriva...  dict
# 18  /Users/xiaoqianxiao/projects/NARSAD/MRI/deriva...  dict
# 19  /Users/xiaoqianxiao/projects/NARSAD/MRI/deriva...  dict
# 20  /Users/xiaoqianxiao/projects/NARSAD/MRI/deriva...  dict
# 21  /Users/xiaoqianxiao/projects/NARSAD/MRI/deriva...  dict
# 22  /Users/xiaoqianxiao/projects/NARSAD/MRI/deriva...  dict
# 23  /Users/xiaoqianxiao/projects/NARSAD/MRI/deriva...  dict
#
#                                                  keys  acc_sad_cv   p_sad  \
# 0   [acc_sad_cv, p_sad, acc_hc_cv, p_hc, func_matr...        0.76  0.0084
# 1   [rdms_sad, rdms_hc, metric_a_stats, metric_b_s...         NaN     NaN
# 2                              [safe_sad, threat_sad]         NaN     NaN
# 3   [stats_safe, stats_threat, data_safe, data_thr...         NaN     NaN
# 4                                     [df_sad, df_hc]         NaN     NaN
# 5                              [df, p_safe, p_threat]         NaN     NaN
# 6                                         [df, stats]         NaN     NaN
# 7                                         [df, stats]         NaN     NaN
# 8                    [acc_plc, acc_oxt, p_val, model]         NaN     NaN
# 9                     [acc_hc_plc, acc_hc_oxt, model]         NaN     NaN
# 10                                                 []         NaN     NaN
# 11                                                 []         NaN     NaN
# 12                                                 []         NaN     NaN
# 13  [ext_early, ext_late, ext_delta, rst_early, rs...         NaN     NaN
# 14  [acc_sad_cv, p_sad, acc_hc_cv, p_hc, func_matr...        0.87  0.0000
# 15  [rdms_sad, rdms_hc, metric_a_stats, metric_b_s...         NaN     NaN
# 16                             [safe_sad, threat_sad]         NaN     NaN
# 17  [stats_safe, stats_threat, data_safe, data_thr...         NaN     NaN
# 18                                    [df_sad, df_hc]         NaN     NaN
# 19                             [df, p_safe, p_threat]         NaN     NaN
# 20                                        [df, stats]         NaN     NaN
# 21                                        [df, stats]         NaN     NaN
# 22                   [acc_plc, acc_oxt, p_val, model]         NaN     NaN
# 23                    [acc_hc_plc, acc_hc_oxt, model]         NaN     NaN
#
#     acc_hc_cv    p_hc  sim_spatial   p_sim  features_sad  features_hc  \
# 0    0.590000  0.1428    -0.034847  0.3708           NaN          NaN
# 1         NaN     NaN          NaN     NaN         109.0        108.0
# 2         NaN     NaN          NaN     NaN           NaN          NaN
# 3         NaN     NaN          NaN     NaN           NaN          NaN
# 4         NaN     NaN          NaN     NaN           NaN          NaN
# 5         NaN     NaN          NaN     NaN           NaN          NaN
# 6         NaN     NaN          NaN     NaN           NaN          NaN
# 7         NaN     NaN          NaN     NaN           NaN          NaN
# 8         NaN     NaN          NaN     NaN           NaN          NaN
# 9         NaN     NaN          NaN     NaN           NaN          NaN
# 10        NaN     NaN          NaN     NaN           NaN          NaN
# 11        NaN     NaN          NaN     NaN           NaN          NaN
# 12        NaN     NaN          NaN     NaN           NaN          NaN
# 13        NaN     NaN          NaN     NaN           NaN          NaN
# 14   0.796667  0.0006     0.067471  0.7384           NaN          NaN
# 15        NaN     NaN          NaN     NaN          21.0         21.0
# 16        NaN     NaN          NaN     NaN           NaN          NaN
# 17        NaN     NaN          NaN     NaN           NaN          NaN
# 18        NaN     NaN          NaN     NaN           NaN          NaN
# 19        NaN     NaN          NaN     NaN           NaN          NaN
# 20        NaN     NaN          NaN     NaN           NaN          NaN
# 21        NaN     NaN          NaN     NaN           NaN          NaN
# 22        NaN     NaN          NaN     NaN           NaN          NaN
# 23        NaN     NaN          NaN     NaN           NaN          NaN
#
#       p_safe  p_threat     p_val
# 0        NaN       NaN       NaN
# 1        NaN       NaN       NaN
# 2        NaN       NaN       NaN
# 3        NaN       NaN       NaN
# 4        NaN       NaN       NaN
# 5   0.980508  0.959993       NaN
# 6        NaN       NaN       NaN
# 7        NaN       NaN       NaN
# 8        NaN       NaN  0.173930
# 9        NaN       NaN       NaN
# 10       NaN       NaN       NaN
# 11       NaN       NaN       NaN
# 12       NaN       NaN       NaN
# 13       NaN       NaN       NaN
# 14       NaN       NaN       NaN
# 15       NaN       NaN       NaN
# 16       NaN       NaN       NaN
# 17       NaN       NaN       NaN
# 18       NaN       NaN       NaN
# 19  0.073626  0.170484       NaN
# 20       NaN       NaN       NaN
# 21       NaN       NaN       NaN
# 22       NaN       NaN  0.725476
# 23       NaN       NaN       NaN
#                                                  file  acc_sad_cv   p_sad  \
# 0   /Users/xiaoqianxiao/projects/NARSAD/MRI/deriva...        0.76  0.0084
# 1   /Users/xiaoqianxiao/projects/NARSAD/MRI/deriva...         NaN     NaN
# 2   /Users/xiaoqianxiao/projects/NARSAD/MRI/deriva...         NaN     NaN
# 3   /Users/xiaoqianxiao/projects/NARSAD/MRI/deriva...         NaN     NaN
# 4   /Users/xiaoqianxiao/projects/NARSAD/MRI/deriva...         NaN     NaN
# 5   /Users/xiaoqianxiao/projects/NARSAD/MRI/deriva...         NaN     NaN
# 6   /Users/xiaoqianxiao/projects/NARSAD/MRI/deriva...         NaN     NaN
# 7   /Users/xiaoqianxiao/projects/NARSAD/MRI/deriva...         NaN     NaN
# 8   /Users/xiaoqianxiao/projects/NARSAD/MRI/deriva...         NaN     NaN
# 9   /Users/xiaoqianxiao/projects/NARSAD/MRI/deriva...         NaN     NaN
# 10  /Users/xiaoqianxiao/projects/NARSAD/MRI/deriva...         NaN     NaN
# 11  /Users/xiaoqianxiao/projects/NARSAD/MRI/deriva...         NaN     NaN
# 12  /Users/xiaoqianxiao/projects/NARSAD/MRI/deriva...         NaN     NaN
# 13  /Users/xiaoqianxiao/projects/NARSAD/MRI/deriva...         NaN     NaN
# 14  /Users/xiaoqianxiao/projects/NARSAD/MRI/deriva...        0.87  0.0000
# 15  /Users/xiaoqianxiao/projects/NARSAD/MRI/deriva...         NaN     NaN
# 16  /Users/xiaoqianxiao/projects/NARSAD/MRI/deriva...         NaN     NaN
# 17  /Users/xiaoqianxiao/projects/NARSAD/MRI/deriva...         NaN     NaN
# 18  /Users/xiaoqianxiao/projects/NARSAD/MRI/deriva...         NaN     NaN
# 19  /Users/xiaoqianxiao/projects/NARSAD/MRI/deriva...         NaN     NaN
# 20  /Users/xiaoqianxiao/projects/NARSAD/MRI/deriva...         NaN     NaN
# 21  /Users/xiaoqianxiao/projects/NARSAD/MRI/deriva...         NaN     NaN
# 22  /Users/xiaoqianxiao/projects/NARSAD/MRI/deriva...         NaN     NaN
# 23  /Users/xiaoqianxiao/projects/NARSAD/MRI/deriva...         NaN     NaN
#
#     acc_hc_cv    p_hc  sim_spatial   p_sim  features_sad  features_hc  \
# 0    0.590000  0.1428    -0.034847  0.3708           NaN          NaN
# 1         NaN     NaN          NaN     NaN         109.0        108.0
# 2         NaN     NaN          NaN     NaN           NaN          NaN
# 3         NaN     NaN          NaN     NaN           NaN          NaN
# 4         NaN     NaN          NaN     NaN           NaN          NaN
# 5         NaN     NaN          NaN     NaN           NaN          NaN
# 6         NaN     NaN          NaN     NaN           NaN          NaN
# 7         NaN     NaN          NaN     NaN           NaN          NaN
# 8         NaN     NaN          NaN     NaN           NaN          NaN
# 9         NaN     NaN          NaN     NaN           NaN          NaN
# 10        NaN     NaN          NaN     NaN           NaN          NaN
# 11        NaN     NaN          NaN     NaN           NaN          NaN
# 12        NaN     NaN          NaN     NaN           NaN          NaN
# 13        NaN     NaN          NaN     NaN           NaN          NaN
# 14   0.796667  0.0006     0.067471  0.7384           NaN          NaN
# 15        NaN     NaN          NaN     NaN          21.0         21.0
# 16        NaN     NaN          NaN     NaN           NaN          NaN
# 17        NaN     NaN          NaN     NaN           NaN          NaN
# 18        NaN     NaN          NaN     NaN           NaN          NaN
# 19        NaN     NaN          NaN     NaN           NaN          NaN
# 20        NaN     NaN          NaN     NaN           NaN          NaN
# 21        NaN     NaN          NaN     NaN           NaN          NaN
# 22        NaN     NaN          NaN     NaN           NaN          NaN
# 23        NaN     NaN          NaN     NaN           NaN          NaN
#
#       p_safe  p_threat     p_val
# 0        NaN       NaN       NaN
# 1        NaN       NaN       NaN
# 2        NaN       NaN       NaN
# 3        NaN       NaN       NaN
# 4        NaN       NaN       NaN
# 5   0.980508  0.959993       NaN
# 6        NaN       NaN       NaN
# 7        NaN       NaN       NaN
# 8        NaN       NaN  0.173930
# 9        NaN       NaN       NaN
# 10       NaN       NaN       NaN
# 11       NaN       NaN       NaN
# 12       NaN       NaN       NaN
# 13       NaN       NaN       NaN
# 14       NaN       NaN       NaN
# 15       NaN       NaN       NaN
# 16       NaN       NaN       NaN
# 17       NaN       NaN       NaN
# 18       NaN       NaN       NaN
# 19  0.073626  0.170484       NaN
# 20       NaN       NaN       NaN
# 21       NaN       NaN       NaN
# 22       NaN       NaN  0.725476
# 23       NaN       NaN       NaN
